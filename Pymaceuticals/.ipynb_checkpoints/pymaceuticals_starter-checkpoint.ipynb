# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
# Display the data table for preview
combined_df = pd.merge(mouse_metadata, study_results, on='Mouse ID')
combined_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
mouse_total = combined_df["Mouse ID"].count()
print(f" There are {mouse_total} mice")
# Out:
#  There are 1893 mice

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_rows = combined_df[combined_df.duplicated(['Mouse ID', 'Timepoint'])]
duplicate_rows
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates_all = combined_df[combined_df.duplicated(['Mouse ID'])]
duplicates_all
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
xduplicates_df = combined_df.drop_duplicates('Mouse ID')
xduplicates_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mouse_total = xduplicates_df["Mouse ID"].count()
print(f" There are {mouse_total} mice")
# Out:
#  There are 249 mice

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
Mean = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
Median = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
Variance = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
Standard_dev = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
SEM = combined_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

stats_summary_df = pd.DataFrame({'Mean': Mean,
                                 'Median': Median, 
                                 'Variance': Variance, 
                                 'Standard Deviation': Standard_dev,
                                 'SEM': SEM
                                })

stats_summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070            6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
aggre_group_by = combined_df.groupby('Drug Regimen')
summary_statsv2 = aggre_group_by.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
summary_statsv2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
data_plot = combined_df.groupby('Drug Regimen').count()['Tumor Volume (mm3)']
bp_data = data_plot.plot.bar(rot='vertical', title='Drug Treatment Count')


bp_data.set_xlabel('Drug Regimen')
bp_data.set_ylabel('Mice Tested')
# Out:
# Text(0, 0.5, 'Mice Tested')

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
data_plot = combined_df.groupby('Drug Regimen').count()['Tumor Volume (mm3)']
data_plot_df = pd.DataFrame(data_plot)


plt.xdata = data_plot_df.plot.bar(legend=False)
plt.xlabel("Drug Regimen")
plt.ylabel("Mice Tested")
plt.title("Drug Treatment Count")
# Out:
# Text(0.5, 1.0, 'Drug Treatment Count')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_grouping = combined_df.groupby(['Mouse ID', 'Sex'])
gender_grouping

gender_df = pd.DataFrame(gender_grouping.size())
gender = pd.DataFrame(gender_df.groupby(['Sex']).count())
gender.columns = ['Total Count']

gender['Percentage of Sex'] = (100*(gender["Total Count"]/gender["Total Count"].sum()))
gender['Percentage of Sex'] = gender['Percentage of Sex']


explode = (0.1, 0)
colors = ['Pink', 'Blue']
plot = gender.plot.pie(y='Total Count',figsize=(5,5), colors = colors, startangle=140, explode=explode, shadow = True, autopct="%1.1f%%")
plt.ylabel('Sex',fontsize = 14)
# Out:
# Text(0, 0.5, 'Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# gender allocation from above 
gender_allocation = [49.799197,50.200803]

labels = ['Female', 'Male']
colors = ['Pink', 'Blue']
explode = (0.1, 0)

plt.pie(gender_allocation, explode=explode, labels=labels, startangle=140, colors=colors, shadow = True, autopct="%1.1f%%")
plt.ylabel('Sex',fontsize = 14)
# Out:
# Text(0, 0.5, 'Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
capomulin_df = combined_df.loc[combined_df["Drug Regimen"] == "Capomulin",:]
ramicane_df = combined_df.loc[combined_df["Drug Regimen"] == "Ramicane",:]
infubinol_df = combined_df.loc[combined_df["Drug Regimen"] == "Infubinol",:]
ceftamin_df = combined_df.loc[combined_df["Drug Regimen"] == "Ceftamin",:]

# Start by getting the last (greatest) timepoint for each mouse
capomulin_max = capomulin_df.groupby('Mouse ID').max()['Timepoint']
capomulin_max_df = pd.DataFrame(capomulin_max)

ramicane_max = ramicane_df.groupby('Mouse ID').max()['Timepoint']
ramicane_max_df = pd.DataFrame(capomulin_max)

infubinol_max = infubinol_df.groupby('Mouse ID').max()['Timepoint']
infubinol_max_df = pd.DataFrame(capomulin_max)

ceftamin_max = ceftamin_df.groupby('Mouse ID').max()['Timepoint']
ceftamin_max_df = pd.DataFrame(capomulin_max)

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
capomulin_max_merge = pd.merge(capomulin_max_df,combined_df,on=("Mouse ID","Timepoint"),how="left")
capomulin_max_merge.head()

ramicane_max_merge = pd.merge(ramicane_max_df,combined_df,on=("Mouse ID","Timepoint"),how="left")
ramicane_max_merge.head()

infubinol_max_merge = pd.merge(infubinol_max_df,combined_df,on=("Mouse ID","Timepoint"),how="left")
infubinol_max_merge.head()

ceftamin_max_merge = pd.merge(ceftamin_max_df,combined_df,on=("Mouse ID","Timepoint"),how="left")
ceftamin_max_merge.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     b128         45    Capomulin  Female           9          22
# 1     b742         45    Capomulin    Male           7          21
# 2     f966         20    Capomulin    Male          16          17
# 3     g288         45    Capomulin    Male           3          19
# 4     g316         45    Capomulin  Female          22          22
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           30.485985                 0
# 3           37.074024                 1
# 4           40.159220                 2

# %%
# Put treatments into a list for for loop (and later for plot labels)
Regimens = ['Capomulin','Ceftamin','Infubinol','Ramicane']

# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
cap_reg = capomulin_max_merge["Tumor Volume (mm3)"]

cap_quartiles = cap_reg.quantile([.25,.5,.75])
cap_lowerq = cap_quartiles[0.25]
cap_upperq = cap_quartiles[0.75]
cap_iqr = cap_upperq-c_lowerq

ram_reg = ramicane_max_merge["Tumor Volume (mm3)"]
ram_quartiles = ram_reg.quantile([.25,.5,.75])
ram_lowerq = ram_quartiles[0.25]
ram_upperq = ram_quartiles[0.75]
ram_iqr = ram_upperq-r_lowerq

inf_reg = infubinol_max_merge["Tumor Volume (mm3)"]
inf_quartiles = inf_reg.quantile([.25,.5,.75])
inf_lowerq = inf_quartiles[0.25]
inf_upperq = inf_quartiles[0.75]
inf_iqr = inf_upperq-i_lowerq

ce_reg = ceftamin_max_merge["Tumor Volume (mm3)"]
ce_quartiles = ce_reg.quantile([.25,.5,.75])
ce_lowerq = ce_quartiles[0.25]
ce_upperq = ce_quartiles[0.75]
ce_iqr = ce_upperq-ce_lowerq
    
# Determine outliers using upper and lower bounds
cap_lower_bound = cap_lowerq - (1.5*c_iqr)
cap_upper_bound = cap_upperq + (1.5*c_iqr)
print(f"Capomulin values below {cap_lower_bound} and above {cap_upper_bound} could be outliers.")

ram_lower_bound = ram_lowerq - (1.5*r_iqr)
ram_upper_bound = ram_upperq + (1.5*r_iqr)
print(f"Ramicane values below {ram_lower_bound} and above {ram_upper_bound} could be outliers.")

inf_lower_bound = inf_lowerq - (1.5*i_iqr)
inf_upper_bound = inf_upperq + (1.5*i_iqr)
print(f"Infubinol values below {inf_lower_bound} and above {inf_upper_bound} could be outliers.")

ce_lower_bound = ce_lowerq - (1.5*ce_iqr)
ce_upper_bound = ce_upperq + (1.5*ce_iqr)
print(f"Ceftamin values below {ce_lower_bound} and above {ce_upper_bound} could be outliers.")
# Out:
# Capomulin values below 20.70456164999999 and above 51.83201549 could be outliers.
# Ramicane values below 20.70456164999999 and above 51.83201549 could be outliers.
# Infubinol values below 20.70456164999999 and above 51.83201549 could be outliers.
# Ceftamin values below 20.70456164999999 and above 51.83201549 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
Regimens = ['Capomulin','Ceftamin','Infubinol','Ramicane']
data_to_plot = [cap_reg, ram_reg, inf_reg, ce_reg]
fig1, ax1 = plt.subplots(figsize=(15, 10))
ax1.set_title('Tumor Vol at Selected Mouse',fontsize = 20)
ax1.set_ylabel('Final Tumor Volume (mm3)',fontsize = 14)
ax1.set_xlabel('Drug Regimen',fontsize = 14)
ax1.boxplot(data_to_plot, labels=Regimens, widths = 0.5, patch_artist=True,vert=True)
plt.ylim(20, 50)

plt.savefig("../Images/box_plot.png", bbox_inches = "tight")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
forline_df = capomulin_df.loc[capomulin_df['Mouse ID'] == "b742",:]
forline_df.head()
# Out:
#     Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 290     b742    Capomulin  Male           7          21          0
# 291     b742    Capomulin  Male           7          21          5
# 292     b742    Capomulin  Male           7          21         10
# 293     b742    Capomulin  Male           7          21         15
# 294     b742    Capomulin  Male           7          21         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 290           45.000000                 0
# 291           41.534097                 0
# 292           41.999228                 0
# 293           39.524843                 0
# 294           37.950355                 0

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
tumor_vol = forline_df["Tumor Volume (mm3)"]
x_axis = forline_df["Timepoint"]

plt.title('Capomulin Treatment')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume')
plt.plot(x_axis,tumor_vol,linewidth=3, markersize=10, marker="o",color="blue", label="Fahreneit")

plt.savefig('linechart')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

capomulin_df_average = capomulin_df.groupby(['Mouse ID']).mean()

x_values = capomulin_df_average['Weight (g)']
y_values = capomulin_df_average['Tumor Volume (mm3)']


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regression_values = x_values * slope + intercept
line_equation = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values, y_values,s=100, color="blue")
plt.plot(x_values,regression_values,"r-")
plt.annotate(line_equation, (30,10), fontsize=10,color="red")

plt.xlabel("Weight")
plt.ylabel("Tumor Volume")
plt.title("Weight vs Avg Tumor Volume")
# Out:
# Text(0.5, 1.0, 'Weight vs Avg Tumor Volume')
